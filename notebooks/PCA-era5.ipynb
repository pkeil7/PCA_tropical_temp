# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.patches as mpatches

import sys
sys.path.append("src")
import PCA_wrappers
sys.path.append("/home/k/k202177/metcalc")
import metcalc

# %%
WORK_DIR = "/work/ka1176/paul/ML_tropospheric_temperatures/data"

# %%
era5
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 996, isobaricInhPa: 5, values: 542080)
# Coordinates:
#   * time           (time) datetime64[ns] 1940-01-01T12:00:00 ... 2022-12-01T1...
#     step           timedelta64[ns] 00:00:00
#   * isobaricInhPa  (isobaricInhPa) float64 400.0 300.0 250.0 200.0 150.0
#     latitude       (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#     longitude      (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#     valid_time     (time) datetime64[ns] dask.array<chunksize=(12,), meta=np.ndarray>
# Dimensions without coordinates: values
# Data variables:
#     t              (time, isobaricInhPa, values) float32 dask.array<chunksize=(12, 5, 542080), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-04-04T09:42 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
era5 = xr.open_mfdataset(WORK_DIR + "/era5/E5pl00_1M_*_130_ut.nc")

# %%
test = era5.isel(time=0,isobaricInhPa=0 )

# %%
plt.scatter(test.longitude,test.latitude,c=test.t)

# %%
era5_norm, era5_mean, era5_std = utils.normalise(era5,["time"])

# %%
era5_stacked = era5.stack("coord", ["lon","lat"])

# %%
era5_PCA = PCA_wrappers.PCA_wrapper(era5_stacked, number_of_PCs = 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 era5_PCA = PCA_wrapper(era5_norm, number_of_PCs = 5)
#
# Cell In[48], line 8, in PCA_wrapper(ds, number_of_PCs, var, level)
#       6 principal.fit(da)
#       7 time_series = principal.transform(da)
# ----> 8 results = xr.DataArray(principal.components_, coords = {"PCAs": np.arange(number_of_PCs) +1, "latitude" : da.latitude, "longitude" : da.longitude}).to_dataset(name="components")
#       9 explained_variance= principal.explained_variance_ratio_
#      11 da = xr.DataArray(time_series, coords = {"time" : ds_stacked.time, "PCAs": np.arange(number_of_PCs) +1 })
#
# File /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/xarray/core/dataarray.py:423, in DataArray.__init__(self, data, coords, dims, name, attrs, indexes, fastpath)
#     421 data = _check_data_shape(data, coords, dims)
#     422 data = as_compatible_data(data)
# --> 423 coords, dims = _infer_coords_and_dims(data.shape, coords, dims)
#     424 variable = Variable(dims, data, attrs, fastpath=True)
#     425 indexes, coords = _create_indexes_from_coords(coords)
#
# File /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/xarray/core/dataarray.py:161, in _infer_coords_and_dims(shape, coords, dims)
#     159 for k, v in new_coords.items():
#     160     if any(d not in dims for d in v.dims):
# --> 161         raise ValueError(
#     162             f"coordinate {k} has dimensions {v.dims}, but these "
#     163             "are not a subset of the DataArray "
#     164             f"dimensions {dims}"
#     165         )
#     167     for d, s in zip(v.dims, v.shape):
#     168         if s != sizes[d]:
#
# ValueError: coordinate PCAs has dimensions ('PCAs',), but these are not a subset of the DataArray dimensions ('dim_0', 'dim_1')

# %%
era5_PCA

# %% [markdown]
# ## PCA

# %%
fig,xs = plt.subplots(len(example.PCAs),1,figsize=(20,10), subplot_kw={'projection': ccrs.PlateCarree(central_longitude=222)})

for i in range(len(example.PCAs)) :
    ax=xs[i]
    example.sel(PCAs=i +1).components.plot(x="lon",y="lat",ax=ax,transform=ccrs.PlateCarree(),cmap='PiYG',cbar_kwargs={"label" : "K"}, vmin=-0.05, vmax=0.05)
    metcalc.set_regional_cartopy(ax)
    ax.set_title(f"{i+1} PC, explained variance = {example.sel(PCAs=i +1).explained_variance.values}")

# %%
fig,xs = plt.subplots(len(example.PCAs),1,figsize=(20,10))

for i in range(len(example.PCAs)) :
    ax=xs[i]
    example.sel(PCAs=i +1).time_series.plot(x="time",ax=ax)
    ax.set_xlabel("Time / years")
    ax.set_ylabel("Non Dimnesional ?")
    ax.set_title(f"{i+1} PC, explained variance = {example.sel(PCAs=i +1).explained_variance.values}")
    
fig.tight_layout()

# %% [markdown]
# ## ICA

# %% [markdown]
# ICA should not be used when data is guassian! This means we probably cant use it here

# %% [markdown]
# ## Try with detrended data

# %%
def detrend(ds,an_dim="model_id") :
    ds_an_trend = ds.polyfit(dim="time", deg=1)
    ds_an = (ds["ta"] - ds.time * ds_an_trend["ta_polyfit_coefficients"].sel(degree=1)).to_dataset(name="ta")
    return ds_an

# %%
ssp585_jan_norm_dt = detrend(ssp585_jan_norm)
# Out:
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/xarray/core/nputils.py:191: RankWarning: Polyfit may be poorly conditioned
#   warn_on_deficient_rank(rank, x.shape[1])
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/xarray/core/nputils.py:191: RankWarning: Polyfit may be poorly conditioned
#   warn_on_deficient_rank(rank, x.shape[1])
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/xarray/core/nputils.py:191: RankWarning: Polyfit may be poorly conditioned
#   warn_on_deficient_rank(rank, x.shape[1])
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/xarray/core/nputils.py:191: RankWarning: Polyfit may be poorly conditioned
#   warn_on_deficient_rank(rank, x.shape[1])
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/xarray/core/nputils.py:191: RankWarning: Polyfit may be poorly conditioned
#   warn_on_deficient_rank(rank, x.shape[1])

# %%
ssp585_jan_norm_dt_PCA = PCA_wrapper(ssp585_jan_norm_dt, number_of_PCs = 5)
ssp585_jan_norm_dt_ICA = ICA_wrapper(ssp585_jan_norm_dt, number_of_PCs = 5)
# Out:
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(

# %%
example = ssp585_jan_norm_dt_PCA.isel(model_id=0)
example_ICA = ssp585_jan_norm_dt_ICA.isel(model_id=0)

# %% [markdown]
# ## PCA

# %%
fig,xs = plt.subplots(len(example.PCAs),1,figsize=(20,10), subplot_kw={'projection': ccrs.PlateCarree(central_longitude=222)})

for i in range(len(example.PCAs)) :
    ax=xs[i]
    example.sel(PCAs=i +1).components.plot(x="lon",y="lat",ax=ax,transform=ccrs.PlateCarree(),cmap='PiYG',cbar_kwargs={"label" : "K"}, vmin=-0.05, vmax=0.05)
    metcalc.set_regional_cartopy(ax)
    ax.set_title(f"{i+1} PC, explained variance = {example.sel(PCAs=i +1).explained_variance.values}")

# %%
fig,xs = plt.subplots(len(example.PCAs),1,figsize=(20,10))

for i in range(len(example.PCAs)) :
    ax=xs[i]
    example.sel(PCAs=i +1).time_series.plot(x="time",ax=ax)
    ax.set_xlabel("Time / years")
    ax.set_ylabel("Non Dimnesional ?")
    ax.set_title(f"{i+1} PC, explained variance = {example.sel(PCAs=i +1).explained_variance.values}")
    
fig.tight_layout()

# %% [markdown]
# ## ICA

# %%
fig,xs = plt.subplots(len(example.PCAs),1,figsize=(20,10), subplot_kw={'projection': ccrs.PlateCarree(central_longitude=222)})

for i in range(len(example.PCAs)) :
    ax=xs[i]
    example_ICA.sel(PCAs=i +1).components.plot(x="lon",y="lat",ax=ax,transform=ccrs.PlateCarree(),cmap='PiYG',cbar_kwargs={"label" : "K"}, vmin=-0.01, vmax=0.01)
    metcalc.set_regional_cartopy(ax)
    ax.set_title(f"{i+1} IC")

# %%
fig,xs = plt.subplots(len(example.PCAs),1,figsize=(20,10))

for i in range(len(example.PCAs)) :
    ax=xs[i]
    example_ICA.sel(PCAs=i +1).time_series.plot(x="time",ax=ax)
    ax.set_xlabel("Time / years")
    ax.set_ylabel("Non Dimnesional ?")
    ax.set_title(f"{i+1} IC")
    
fig.tight_layout()

# %%
# !ls -l /work/ik1017/Catalogs
# Out:
# total 4778340
# drwxrwxr-x  2 k204210 ik1017      12288 Apr 18  2023 archive
# drwxr-sr-x. 3 k204210 ik1017       4096 Nov 22  2022 Candidates
# -rwxrwxr-x  1 k204210 ik1017    1330797 Feb 27  2022 cmip6-retracted-outdated.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       1802 Apr 14  2022 cmip6-retracted-outdated.json
# -rwxr-xr-x. 1 k204210 ik1017       6270 May 26  2023 dkrz_catalog.yaml
# -rw-r--r--. 1 k204210 ik1017   49651280 Jun 17  2022 dkrz_cmip5_archive.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2199 Jun 17  2022 dkrz_cmip5_archive.json
# -rwxr-xr--. 1 k204210 ik1017   19976874 Apr 14  2023 dkrz_cmip5_disk.csv.gz
# -rwxrwxr-x. 1 k204210 ik1017       2531 Jun 17  2022 dkrz_cmip5_disk.json
# -rwxrwxr-x  1 k204210 ik1017   32141206 Aug  5  2021 dkrz_cmip5_disk_netcdf.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2111 Apr 14  2022 dkrz_cmip5_disk_netcdf.json
# -rwxrwxr-x  1 k204210 ik1017   39247019 Dec 13  2022 dkrz_cmip6_archive.csv.gz
# -rw-r--r--  1 k204210 ik1017       6703 May  9  2022 dkrz_cmip6_cloud.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2612 Jun 17  2022 dkrz_cmip6_cloud.json
# -rw-r--r--. 1 b381897 ik1017 3854888960 Jun  2  2022 dkrz_cmip6_disk.csv
# -rwxrwxr-x. 1 k204210 ik1017  150038478 Apr 18  2023 dkrz_cmip6_disk.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       4232 Jun 17  2022 dkrz_cmip6_disk.json
# -rwxrwxr-x  1 k204210 ik1017   79727316 Feb 28  2022 dkrz_cmip6_disk_netcdf.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       3013 Apr 14  2022 dkrz_cmip6_disk_netcdf.json
# -rwxrwxr-x  1 k204210 ik1017  163116985 Sep 24  2021 dkrz_cmip6pids_disk_netcdf.csv.gz
# -rwxrwxr-x  1 k204210 ik1017     998653 Sep 15  2021 dkrz_cmip6_swift_zarr.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2382 Apr 14  2022 dkrz_cmip6_swift_zarr.json
# -rwxrwxr-x  1 k204210 ik1017  101185421 Sep 15  2021 dkrz_cmip-data-pool_disk_netcdf.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2703 Apr 14  2022 dkrz_cmip-data-pool_disk_netcdf.json
# -rw-r--r--. 1 k204210 ik1017   34312462 Oct 13  2022 dkrz_cordex_disk.csv.gz
# -rwxrwxr-x. 1 k204210 ik1017       2751 Jun 17  2022 dkrz_cordex_disk.json
# -rwxr-xr-x  1 k204210 ik1017       2006 Sep 15  2021 dkrz_data-pool_diskcatalog.yaml
# -rwxrwxr-x  1 k204210 bm0021   43278351 Apr 19  2023 dkrz_dyamond-winter_disk.json
# -rwxrwxr-x  1 k204210 ik1017   35000807 Jun 30  2023 dkrz_era5_disk.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2543 Apr 14  2023 dkrz_era5_disk.json
# -rw-r--r--  1 k204210 ik1017      15973 Nov 22  2022 dkrz_monsoon_disk.yaml
# -rw-r--r--  1 k204210 ik1017     754454 Oct 18  2022 dkrz_mpige_disk.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2530 Oct 18  2022 dkrz_mpige_disk.json
# -rwxrwxr-x  1 k204210 bm0021   64578253 Apr 19  2023 dkrz_nextgems_disk.json
# -rwxrwxr-x. 1 k204210 ik1017     474286 Apr 14  2022 dkrz_palmod2_disk.csv.gz
# -rwxrwxr-x. 1 k204210 ik1017       2519 Jun 17  2022 dkrz_palmod2_disk.json
# drwxr-sr-x  3 k204210 ik1017       4096 Nov 22  2022 highresmonsoon
# -rwxr-xr-x. 1 k204210 ik1017       3189 Apr 14  2022 intake-esm_template_cmip6.json
# -rwxrwxr-x  1 k204210 ik1017   29507786 Mar  5  2021 mistral-cmip6-cmip.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       3009 Apr 14  2022 mistral-cmip6-cmip.json
# -rwxrwxr-x  1 k204210 ik1017  162526569 Aug  2  2021 mistral-cmip6-pids.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       3009 Apr 14  2022 mistral-cmip6-pids.json
# -rwxrwxr-x  1 k204210 ik1017   15027938 Mar  5  2021 mistral-cmip6-scenariomip.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       3016 Apr 14  2022 mistral-cmip6-scenariomip.json
# -rwxrwxr-x  1 k204210 ik1017   15031962 Nov 13  2019 mistral-miklip.csv.gz
# -rwxrwxr-x  1 k204210 ik1017       2234 Apr 14  2022 mistral-miklip.json
# drwxrwsr-x  6 k204210 ik1017       4096 Nov 13  2019 ncar-intake-esm-datastore
# -rwxr-xr-x. 1 b381897 ik1017       3003 Jun  1  2022 new-mistral-cmip6-scenariomip.json
# -rwxrwxr-x  1 k204210 ik1017       2707 Apr 14  2022 pangeo-cmip6.json
# -rw-r--r--. 1 k204235 ik1017       8179 Jun 29  2022 stac_cmip6_test.csv.gz
# drwxr-sr-x. 3 k204210 ik1017       4096 Mar 29  2022 Templates

# %%
import intake
import intake_esm

# %%
# !ls /pool/data/ERA5/E5/pl/an/1M/
# Out:
# 060  075  076  129  130  131  132  133	135  138  155  157  203  246  247  248

# %% [markdown]
# temperature has 130

# %%
directory = "/pool/data/ERA5/E5/pl/an/1M/130"

# %% [markdown]
# https://docs.dkrz.de/doc/dataservices/finding_and_accessing_data/era_data/index.html

# %%
test = intake.open_esm_datastore(
    "/work/ik1017/Catalogs/dkrz_era5_disk.json")
# Out:
# /work/ka1176/paul/conda/ML_trop_temp/lib/python3.11/site-packages/intake_esm/cat.py:249: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
test.df.head()
# Out:
#   project institution_id source_id era_id dataType   level_type frequency  \
# 0    era5          ecmwf       IFS     E1       an  model_level    hourly
# 1    era5          ecmwf       IFS     E1       an  model_level    hourly
# 2    era5          ecmwf       IFS     E1       an  model_level    hourly
# 3    era5          ecmwf       IFS     E1       an  model_level    hourly
# 4    era5          ecmwf       IFS     E1       an  model_level    hourly
#
#   stepType  table_id  code short_name                    long_name      units  \
# 0  instant       128    75       crwc  Specific rain water content  kg kg**-1
# 1  instant       128    75       crwc  Specific rain water content  kg kg**-1
# 2  instant       128    75       crwc  Specific rain water content  kg kg**-1
# 3  instant       128    75       crwc  Specific rain water content  kg kg**-1
# 4  instant       128    75       crwc  Specific rain water content  kg kg**-1
#
#   validation_date initialization_date  \
# 0      2000-01-01               False
# 1      2000-01-02               False
# 2      2000-01-03               False
# 3      2000-01-04               False
# 4      2000-01-05               False
#
#                                                  uri  \
# 0  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...
# 1  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...
# 2  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...
# 3  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...
# 4  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...
#
#                                                 path format
# 0  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...   grib
# 1  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...   grib
# 2  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...   grib
# 3  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...   grib
# 4  /work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_20...   grib

# %%
test.unique()
# Out:
# project                                                           [era5]
# institution_id                                                   [ecmwf]
# source_id                                                          [IFS]
# era_id                                                      [E1, E5, ET]
# dataType                                                        [an, fc]
# level_type                        [model_level, pressure_level, surface]
# frequency                                     [hourly, daily, invariant]
# stepType                                      [instant, avg, max, accum]
# table_id                                                      [128, 256]
# code                   [75, 76, 77, 129, 130, 131, 132, 133, 135, 138...
# short_name             [crwc, cswc, etadot, z, t, u, v, q, w, vo, lns...
# long_name              [Specific rain water content, Specific snow wa...
# units                  [kg kg**-1, s**-1, m**2 s**-2, K, m s**-1, Pa ...
# validation_date        [2000-01-01, 2000-01-02, 2000-01-03, 2000-01-0...
# initialization_date    [False, False, 2000-01, 2000-02, 2000-03, 2000...
# uri                    [/work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_2...
# path                   [/work/bk1099/data/E1/ml/an/1H/075/E1ml00_1H_2...
# format                                                            [grib]
# derived_short_name                                                    []
# dtype: object

# %%
query = dict(
    #era_id="E5",
    level_type="pressure_level",
    frequency="daily",
    #short_name="t"
)

# %%
test.search(**query)
# Out:
# <p><strong>dkrz_era5_disk catalog with 0 dataset(s) from 0 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>project</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>era_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>dataType</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>level_type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>stepType</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>code</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>short_name</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>validation_date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>initialization_date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>uri</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>format</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>derived_short_name</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
